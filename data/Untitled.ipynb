# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from datetime import datetime

# %%
data = pd.read_csv("us_daily.csv", delimiter=",")
data.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200516      56   1433696  9286489.0   2457.0                42854.0
# 1  20200515      56   1433696  9286489.0   2457.0                42854.0
# 2  20200514      56   1407507  8934268.0   2673.0                44317.0
# 3  20200513      56   1382304  8592527.0   1983.0                44514.0
# 4  20200512      56   1361884  8288521.0   1803.0                45199.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                153866.0         10704.0           6890.0
# 1                153866.0         10704.0           6890.0
# 2                152396.0         10901.0           6795.0
# 3                149347.0         10978.0           6713.0
# 4                147250.0         11241.0           5595.0
#
#    onVentilatorCurrently  ...  hospitalized     total totalTestResults  \
# 0                 5746.0  ...      153866.0  10722642         10720185
# ...

# %%
data.date = pd.to_datetime(data.date, format='%Y%m%d')
data.head()
# Out:
#         date  states  positive   negative  pending  hospitalizedCurrently  \
# 0 2020-05-16      56   1433696  9286489.0   2457.0                42854.0
# 1 2020-05-15      56   1433696  9286489.0   2457.0                42854.0
# 2 2020-05-14      56   1407507  8934268.0   2673.0                44317.0
# 3 2020-05-13      56   1382304  8592527.0   1983.0                44514.0
# 4 2020-05-12      56   1361884  8288521.0   1803.0                45199.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                153866.0         10704.0           6890.0
# 1                153866.0         10704.0           6890.0
# 2                152396.0         10901.0           6795.0
# 3                149347.0         10978.0           6713.0
# 4                147250.0         11241.0           5595.0
#
#    onVentilatorCurrently  ...  hospitalized     total totalTestResults  \
# 0                 5746.0  ...      153866.0  10722642         10720185
# ...

# %%
type(data.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data.plot(kind='line',x='date', y='positive', logy=True)
